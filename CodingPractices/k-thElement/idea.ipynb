# %% [markdown]
# # Find the kth element in an array in descending order
#
# Find the $k$th element in an array in descending order without ordering it.

# %%
import random
from time import time

# %% [markdown]
# Let us guess a value $t$ for the $k$th element and let $b$ be the number of elements in `arr` that is (strictly) bigger than $t$ and $e$ be that equal to $t$, then we have three cases:
#  - if $b < k $ and $b + e \geq k$, we have the $k$-th element must be $t$;
#  - if $b \geq k$ we have increase $t$;
#  - if $b + e < k$, we have decrease $t$;
#
#  The smallest possible $t$ is the minimum of the array and the biggest possible is the maximum.
#  Hence we just need to a binary search in this range

# %%
def getKth(arr, k):
    lo, hi = min(arr), max(arr) + 1
    while hi > lo:
        m = (lo + hi) // 2
        
        b = sum([a > m for a in arr]) 
        e = sum([a == m for a in arr])
        
        # print(f'{m}, {b}, {b + e}')
        if b < k and b + e >= k:
            return m
        elif b >= k:
            lo = m + 1
        else:
            hi = m
    return lo

# %%
num_runs = 100

N = 200000
runtimes = []
for i in range(num_runs):
    arr = [random.randint(1, int(1.5 * N)) for _ in range(N)]
    k = random.randint(1, N)
    
    time0 = time() 
    brr = sorted(arr, reverse=True)
    time1 = time()
    sorting = time1 - time0

    time0 = time()
    kth = getKth(arr, k)
    time1 = time()
    bisearch = time1 - time0
    
    print(f'{i + 1}/{num_runs}: {kth}, {brr[k - 1]}')
    print(f'\t{sorting:.6f}, {bisearch:.6f}')
    runtimes.append([sorting, bisearch])
# Out:
# 1/100: 195026, 195026
# 	0.072127, 0.675853
# 2/100: 23143, 23143
# 	0.079581, 0.634959
# 3/100: 256195, 256195
# 	0.073971, 0.722534
# 4/100: 226199, 226199
# 	0.082147, 0.805755
# 5/100: 28713, 28713
# 	0.080606, 0.730225
# 6/100: 37913, 37913
# 	0.078215, 0.935649
# 7/100: 50372, 50372
# 	0.074256, 0.688878
# 8/100: 102167, 102167
# 	0.075581, 0.767812
# 9/100: 4878, 4878
# 	0.071001, 0.744803
# 10/100: 91107, 91107
# 	0.081354, 0.881377
# 11/100: 54930, 54930
# 	0.080541, 0.620109
# 12/100: 89311, 89311
# 	0.085215, 0.739789
# 13/100: 96058, 96058
# 	0.076439, 0.538462
# 14/100: 97576, 97576
# 	0.081581, 0.858392
# 15/100: 107034, 107034
# 	0.073624, 0.743689
# 16/100: 123433, 123433
# 	0.075610, 0.788544
# 17/100: 13014, 13014
# 	0.073444, 0.903306
# 18/100: 234850, 234850
# 	0.080338, 0.728270
# 19/100: 18116, 18116
# 	0.087906, 0.753984
# 20/100: 202101, 202101
# 	0.078143, 0.686982
# 21/100: 79866, 79866
# 	0.077582, 0.690446
# 22/100: 85339, 85339
# 	0.080149, 0.987372
# 23/100: 121271, 121271
# 	0.073816, 0.754356
# 24/100: 193314, 193314
# 	0.075268, 0.788157
# 25/100: 98723, 98723
# 	0.083914, 0.763911
# 26/100: 266749, 266749
# 	0.087453, 0.464606
# 27/100: 48265, 48265
# 	0.149283, 1.024718
# 28/100: 37002, 37002
# 	0.078275, 0.788839
# 29/100: 228398, 228398
# 	0.072557, 0.614229
# 30/100: 32573, 32573
# 	0.082711, 0.869691
# 31/100: 38821, 38821
# 	0.075530, 0.764884
# 32/100: 14450, 14450
# 	0.074563, 0.577509
# 33/100: 117292, 117292
# 	0.080601, 0.792661
# 34/100: 3802, 3802
# 	0.074944, 0.632718
# 35/100: 38709, 38709
# 	0.074852, 0.902015
# 36/100: 164875, 164875
# 	0.071518, 0.724900
# 37/100: 162777, 162777
# 	0.079400, 0.735775
# 38/100: 186826, 186826
# 	0.079299, 0.791249
# 39/100: 43295, 43295
# 	0.080433, 0.765567
# 40/100: 159538, 159538
# 	0.073403, 0.803499
# 41/100: 231767, 231767
# 	0.083304, 0.644642
# 42/100: 154554, 154554
# 	0.070940, 0.822240
# 43/100: 49503, 49503
# 	0.071722, 0.735380
# 44/100: 199049, 199049
# 	0.070199, 0.834679
# 45/100: 166699, 166699
# 	0.070050, 0.788400
# 46/100: 27132, 27132
# 	0.077725, 0.728383
# 47/100: 287461, 287461
# 	0.070155, 0.640494
# 48/100: 267076, 267076
# 	0.077240, 0.813691
# 49/100: 104982, 104982
# 	0.073203, 0.795870
# 50/100: 259391, 259391
# 	0.068433, 0.741420
# 51/100: 211454, 211454
# 	0.069889, 0.778157
# 52/100: 207281, 207281
# 	0.071061, 0.776096
# 53/100: 39483, 39483
# 	0.084837, 0.708270
# 54/100: 238123, 238123
# 	0.072308, 0.803754
# 55/100: 211584, 211584
# 	0.083501, 0.773042
# 56/100: 225198, 225198
# 	0.081048, 0.754729
# 57/100: 149560, 149560
# 	0.085741, 0.813236
# 58/100: 204767, 204767
# 	0.073943, 0.797976
# 59/100: 72419, 72419
# 	0.081818, 0.791691
# 60/100: 64285, 64285
# 	0.083597, 0.737148
# 61/100: 154757, 154757
# 	0.068990, 0.775849
# 62/100: 122640, 122640
# 	0.082836, 0.815736
# 63/100: 285397, 285397
# 	0.070657, 0.742856
# 64/100: 9974, 9974
# 	0.081428, 0.753744
# 65/100: 90401, 90401
# 	0.072900, 0.604760
# 66/100: 155258, 155258
# 	0.078252, 0.877424
# 67/100: 74649, 74649
# 	0.080906, 0.638528
# 68/100: 241887, 241887
# 	0.073400, 0.759498
# 69/100: 134304, 134304
# 	0.068932, 0.714872
# 70/100: 140882, 140882
# 	0.074431, 0.810600
# 71/100: 13285, 13285
# 	0.073872, 0.706031
# 72/100: 21188, 21188
# 	0.074409, 0.591546
# 73/100: 257156, 257156
# 	0.074484, 0.760443
# 74/100: 294772, 294772
# 	0.073824, 0.731939
# 75/100: 136635, 136635
# 	0.087969, 0.583299
# 76/100: 3869, 3869
# 	0.070675, 0.724542
# 77/100: 51008, 51008
# 	0.077158, 0.702832
# 78/100: 59888, 59888
# 	0.080349, 0.814851
# 79/100: 132335, 132335
# 	0.069466, 0.822902
# 80/100: 3062, 3062
# 	0.070258, 0.696680
# 81/100: 243418, 243418
# 	0.071802, 0.677166
# 82/100: 127497, 127497
# 	0.079671, 0.797160
# 83/100: 269832, 269832
# 	0.074051, 0.791480
# 84/100: 230357, 230357
# 	0.086905, 0.752891
# 85/100: 198828, 198828
# 	0.070259, 0.827546
# 86/100: 82719, 82719
# 	0.082977, 0.785271
# 87/100: 11491, 11491
# 	0.075194, 0.729162
# 88/100: 42323, 42323
# 	0.072753, 0.742553
# 89/100: 45017, 45017
# 	0.073276, 0.755433
# 90/100: 78012, 78012
# 	0.083136, 0.740805
# 91/100: 139286, 139286
# 	0.075168, 0.768806
# 92/100: 88554, 88554
# 	0.076853, 0.822855
# 93/100: 64812, 64812
# 	0.072600, 0.772656
# 94/100: 152958, 152958
# 	0.081644, 0.814804
# 95/100: 233948, 233948
# 	0.088262, 0.795544
# 96/100: 53161, 53161
# 	0.080841, 0.709015
# 97/100: 118289, 118289
# 	0.072030, 0.856896
# 98/100: 173214, 173214
# 	0.079258, 0.760253
# 99/100: 57641, 57641
# 	0.081246, 0.712754
# 100/100: 119723, 119723
# 	0.074684, 0.809694
