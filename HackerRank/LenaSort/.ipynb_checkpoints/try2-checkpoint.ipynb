# %%
from time import time
import matplotlib.pyplot as plt
import sys
import pandas as pd
import numpy as np
sys.setrecursionlimit(100000)

# %%
def get_smallest(length):
    smallest = [0, 0]
    for l in range(len(smallest), length + 1):
        s = smallest[(l - 1) // 2] + smallest[l // 2] + l - 1
        smallest.append(s)
    return smallest

# %%
def plot_1(length, comparisons):
    smallest = get_smallest(length)
    X, C, S, B = [], [], [], []
    comparisons -= length - 1
    for less in range(length):
        max_less = less * (less - 1) // 2
        comparisons_more = comparisons - max_less

        X.append(less)
        C.append(comparisons_more)

        more = length - 1 - less
        S.append(smallest[more])
        B.append(more * (more - 1) // 2)
    fig, ax = plt.subplots(1, 1, figsize=(10, 5))
    ax.scatter(X, C, label='comparisons')
    ax.scatter(X, S, label='minimum')
    ax.scatter(X, B, label='maximum')
    ax.legend()
    plt.show()
    
plot_1(8, 14)

# %%
get_smallest(8)
# Out:
# [0, 0, 1, 2, 4, 6, 8, 10, 13]

# %%
def plot_2(length, comparisons):
    smallest = get_smallest(length)
    L, U = [], []
    
    max_less_V, min_less_V = [], []
    max_more_V, min_more_V = [], []
    for less in range(length):
        more = length - 1 - less
        max_more, min_more = more * (more - 1) // 2, smallest[more]
        max_less, min_less = less * (less - 1) // 2, smallest[less]
        
        max_less_V.append(max_less)
        min_less_V.append(min_less)
        max_more_V.append(comparisons - max_more)
        min_more_V.append(comparisons - min_more)

        lower = max(min_less, comparisons - max_more)
        upper = min(max_less, comparisons - min_more)
        L.append(lower)
        U.append(upper)
    
    fig, ax = plt.subplots(1, 1, figsize=(10, 6))
    # ax.scatter(range(length), L, label='lower')
    # ax.scatter(range(length), U, label='upper')
    
    # ax.plot(min_less_V, label='less min')
    # ax.plot(max_more_V, label='c - more max')
    
    ax.plot(max_less_V, label='less max')
    ax.plot(min_more_V, label='c - more min')

    ax.legend()
    plt.show()
    
plot_2(100, 2500)

# %%
def lena_sort(arr):
    if len(arr) == 0:
        return [], 0
    if len(arr) == 1:
        return arr, 0

    pivot = arr[0]
    less, more = [], []
    for a in arr[1:]:
        if a < pivot:
            less.append(a)
        else:
            more.append(a)
    
    less_sorted, less_comparisons = lena_sort(less)
    more_sorted, more_comparisons = lena_sort(more)
    arr_sorted = less_sorted + [pivot] + more_sorted
    comparisons = less_comparisons + more_comparisons + len(arr) - 1

    return arr_sorted, comparisons

# %%
def get_min_arr(length, start):
    """
    get the array with integer 0, ..., n-1 such that
    it requires the minimum number of comparison
    when applying QuickSort.
    """
    if length == 0:
        return []
    if length == 1:
        return [0]
    
    memo = [(0, length)]
    while len(memo) < length:
        new_memo = []
        for m in memo:
            if isinstance(m, int):
                new_memo.append(m)
            else:
                s, l = m
                middle = s + (l - 1) // 2
                new_memo.append(middle)
                s_less, l_less = s, (l - 1) // 2
                s_more, l_more = middle + 1, l // 2
                if l_less == 1:
                    new_memo.append(s_less)
                elif l_less > 1:
                    new_memo.append((s_less, l_less))
                if l_more == 1:
                    new_memo.append(s_more)
                elif l_more > 1:
                    new_memo.append((s_more, l_more))
        memo = new_memo
    
    return [start + m for m in memo]


def rec(length, comparisons, first):

    if length == 0:
        return []
    if length == 1:
        return [first]
    
    comparisons -= length - 1

    for less in range((length + 1) // 2):#[::-1]:
        more = length - 1 - less
        max_more, min_more = more * (more - 1) // 2, smallest[more]
        max_less, min_less = less * (less - 1) // 2, smallest[less]
        lower = max(min_less, comparisons - max_more)
        upper = min(max_less, comparisons - min_more)
        if upper >= lower:
            break
    
    pivot = first + less
    print(f'\nlength={length}, comparison={comparisons}, less={less}')
#     print(f'\tless = {less}, more = {more}')
#     print(f'\tless half: ({min_less}, {max_less})')
#     print(f'\tmore half: ({min_more}, {max_more})')
#     print(f'\t(lower, upper) = ({lower}, {upper})')
    if lower == comparisons - max_more:     # comparisons_more = max_more
        
        comparisons_less = lower        
        A = rec(less, comparisons_less, first)
        B = list(range(pivot + 1, pivot + 1 + more))
    elif upper == comparisons - min_more:   # comparisons_more = min_more
        comparisons_less = upper        
        A = rec(less, comparisons_less, first)
        B = get_min_arr(more, pivot + 1)
    else: # upper == max_less
        comparisons_less = upper
        comparisons_more = comparisons - comparisons_less
        A = list(range(first, first + less))
        B = rec(more, comparisons_more, pivot + 1)

    return [pivot] + A + B


def find_arr(length, comparisons):
    comparisons -= length - 1
    for less in range(length)[::-1]:
        max_less = less * (less - 1) // 2
        more = length - 1 - less
        comparisons_more = comparisons - max_less
        if comparisons_more >= smallest[more] and comparisons_more <= (more - 1) * more // 2:
            break 
    pivot = less + 1
    more = length - 1 - less
    
    # print(f'pivot = {pivot}, less = {less}, more = {more}, comparisons_more = {comparisons_more}')
    return [pivot] + list(range(1, pivot)) + rec(more, comparisons_more, pivot + 1)


length, comparisons = 10, 33
length, comparisons = 100000, 323932335
length, comparisons = 6375, 14536397
length, comparisons = 6375, 20166666
smallest = get_smallest(length)

time0 = time()
arr = find_arr(length, comparisons)
print('done')
time1 = time()
print(f'{time1 - time0:.3f}')
print(len(set(arr)) == length)
# arr_sorted, comparisons = lena_sort(arr)

# print(arr)
# print(arr_sorted == list(range(1, length + 1)), comparisons)
# Out:
# length=6351, comparison=20153689, less=0
#
# length=6350, comparison=20147340, less=0
#
# length=6349, comparison=20140992, less=0
#
# length=6348, comparison=20134645, less=0
#
# length=6347, comparison=20128299, less=0
#
# length=6346, comparison=20121954, less=0
#
# length=6345, comparison=20115610, less=0
#
# length=6344, comparison=20109267, less=0
#
# length=6343, comparison=20102925, less=0
#
# length=6342, comparison=20096584, less=0
#
# length=6341, comparison=20090244, less=0
#
# length=6340, comparison=20083905, less=0
#
# length=6339, comparison=20077567, less=0
#
# length=6338, comparison=20071230, less=0
#
# length=6337, comparison=20064894, less=0
#
# length=6336, comparison=20058559, less=0
#
# length=6335, comparison=20052225, less=0
#
# length=6334, comparison=20045892, less=0
#
# length=6333, comparison=20039560, less=0
#
# length=6332, comparison=20033229, less=0
#
# length=6331, comparison=20026899, less=0
#
# length=6330, comparison=20020570, less=0
#
# length=6329, comparison=20014242, less=0
#
# length=6328, comparison=20007915, less=0
#
# length=6327, comparison=20001589, less=0
#
# length=6326, comparison=19995264, less=0
#
# length=6325, comparison=19988940, less=0
#
# length=6324, comparison=19982617, less=0
#
# length=6323, comparison=19976295, less=0
#
# length=6322, comparison=19969974, less=0
#
# length=6321, comparison=19963654, less=0
#
# length=6320, comparison=19957335, less=0
#
# length=6319, comparison=19951017, less=0
#
# length=6318, comparison=19944700, less=0
#
# length=6317, comparison=19938384, less=0
#
# length=6316, comparison=19932069, less=0
#
# length=6315, comparison=19925755, less=0
#
# length=6314, comparison=19919442, less=0
#
# length=6313, comparison=19913130, less=0
#
# length=6312, comparison=19906819, less=0
#
# length=6311, comparison=19900509, less=0
#
# length=6310, comparison=19894200, less=0
#
# length=6309, comparison=19887892, less=0
#
# length=6308, comparison=19881585, less=0
#
# length=6307, comparison=19875279, less=0
#
# length=6306, comparison=19868974, less=0
#
# length=6305, comparison=19862670, less=0
#
# length=6304, comparison=19856367, less=0
#
# length=6303, comparison=19850065, less=0
#
# length=6302, comparison=19843764, less=0
#
# length=6301, comparison=19837464, less=0
#
# length=6300, comparison=19831165, less=0
#
# length=6299, comparison=19824867, less=0
#
# length=6298, comparison=19818570, less=0
#
# length=6297, comparison=19812274, less=0
#
# length=6296, comparison=19805979, less=0
#
# length=6295, comparison=19799685, less=0
#
# length=6294, comparison=19793392, less=0
#
# length=6293, comparison=19787100, less=0
#
# length=6292, comparison=19780809, less=0
#
# length=6291, comparison=19774519, less=0
#
# length=6290, comparison=19768230, less=0
#
# length=6289, comparison=19761942, less=0
#
# length=6288, comparison=19755655, less=0
#
# length=6287, comparison=19749369, less=0
#
# length=6286, comparison=19743084, less=0
#
# length=6285, comparison=19736800, less=0
#
# length=6284, comparison=19730517, less=0
#
# length=6283, comparison=19724235, less=0
#
# length=6282, comparison=19717954, less=0
#
# length=6281, comparison=19711674, less=0
#
# length=6280, comparison=19705395, less=0
#
# length=6279, comparison=19699117, less=0
#
# length=6278, comparison=19692840, less=0
#
# length=6277, comparison=19686564, less=0
#
# length=6276, comparison=19680289, less=0
#
# length=6275, comparison=19674015, less=0
#
# length=6274, comparison=19667742, less=0
#
# length=6273, comparison=19661470, less=0
#
# length=6272, comparison=19655199, less=0
#
# length=6271, comparison=19648929, less=0
#
# length=6270, comparison=19642660, less=0
#
# length=6269, comparison=19636392, less=0
#
# length=6268, comparison=19630125, less=0
#
# length=6267, comparison=19623859, less=0
#
# length=6266, comparison=19617594, less=0
#
# length=6265, comparison=19611330, less=0
#
# length=6264, comparison=19605067, less=0
#
# length=6263, comparison=19598805, less=0
#
# length=6262, comparison=19592544, less=0
#
# length=6261, comparison=19586284, less=0
#
# length=6260, comparison=19580025, less=0
#
# length=6259, comparison=19573767, less=0
#
# length=6258, comparison=19567510, less=0
#
# length=6257, comparison=19561254, less=0
#
# length=6256, comparison=19554999, less=0
#
# length=6255, comparison=19548745, less=0
#
# length=6254, comparison=19542492, less=0
#
# length=6253, comparison=19536240, less=0
#
# length=6252, comparison=19529989, less=0
#
# length=6251, comparison=19523739, less=0
#
# length=6250, comparison=19517490, less=0
#
# length=6249, comparison=19511242, less=0
#
# length=6248, comparison=19504995, less=0
#
# length=6247, comparison=19498749, less=0
#
# length=6246, comparison=19492504, less=0
#
# length=6245, comparison=19486260, less=0
#
# length=6244, comparison=19480017, less=0
#
# length=6243, comparison=19473775, less=0
#
# length=6242, comparison=19467534, less=0
#
# length=6241, comparison=19461294, less=0
#
# length=6240, comparison=19455055, less=0
#
# length=6239, comparison=19448817, less=0
#
# length=6238, comparison=19442580, less=0
#
# length=6237, comparison=19436344, less=0
#
# length=6236, comparison=19430109, less=0
#
# length=6235, comparison=19423875, less=0
#
# length=6234, comparison=19417642, less=0
#
# length=6233, comparison=19411410, less=0
#
# length=6232, comparison=19405179, less=0
#
# length=6231, comparison=19398949, less=0
#
# length=6230, comparison=19392720, less=0
#
# length=6229, comparison=19386492, less=0
#
# length=6228, comparison=19380265, less=0
#
# length=6227, comparison=19374039, less=0
#
# length=6226, comparison=19367814, less=0
#
# length=6225, comparison=19361590, less=0
#
# length=6224, comparison=19355367, less=0
#
# length=6223, comparison=19349145, less=0
#
# length=6222, comparison=19342924, less=0
#
# length=6221, comparison=19336704, less=0
#
# length=6220, comparison=19330485, less=0
#
# length=6219, comparison=19324267, less=0
#
# length=6218, comparison=19318050, less=0
#
# length=6217, comparison=19311834, less=0
#
# length=6216, comparison=19305619, less=0
#
# length=6215, comparison=19299405, less=0
#
# length=6214, comparison=19293192, less=0
#
# length=6213, comparison=19286980, less=0
#
# length=6212, comparison=19280769, less=0
#
# length=6211, comparison=19274559, less=0
#
# length=6210, comparison=19268350, less=0
#
# length=6209, comparison=19262142, less=0
#
# length=6208, comparison=19255935, less=0
#
# length=6207, comparison=19249729, less=0
#
# length=6206, comparison=19243524, less=0
#
# length=6205, comparison=19237320, less=0
#
# length=6204, comparison=19231117, less=0
#
# length=6203, comparison=19224915, less=0
#
# length=6202, comparison=19218714, less=0
#
# length=6201, comparison=19212514, less=0
#
# length=6200, comparison=19206315, less=0
#
# length=6199, comparison=19200117, less=0
#
# length=6198, comparison=19193920, less=0
#
# length=6197, comparison=19187724, less=0
#
# length=6196, comparison=19181529, less=0
#
# length=6195, comparison=19175335, less=0
#
# length=6194, comparison=19169142, less=0
#
# length=6193, comparison=19162950, less=0
#
# length=6192, comparison=19156759, less=0
#
# length=6191, comparison=19150569, less=0
#
# length=6190, comparison=19144380, less=0
#
# length=6189, comparison=19138192, less=0
#
# length=6188, comparison=19132005, less=0
#
# length=6187, comparison=19125819, less=0
#
# length=6186, comparison=19119634, less=0
#
# length=6185, comparison=19113450, less=0
#
# length=6184, comparison=19107267, less=0
#
# length=6183, comparison=19101085, less=0
#
# length=6182, comparison=19094904, less=0
#
# length=6181, comparison=19088724, less=0
#
# length=6180, comparison=19082545, less=0
#
# length=6179, comparison=19076367, less=0
#
# length=6178, comparison=19070190, less=0
#
# length=6177, comparison=19064014, less=0
#
# length=6176, comparison=19057839, less=0
#
# length=6175, comparison=19051665, less=0
#
# length=6174, comparison=19045492, less=0
#
# length=6173, comparison=19039320, less=0
#
# length=6172, comparison=19033149, less=0
#
# length=6171, comparison=19026979, less=0
#
# length=6170, comparison=19020810, less=0
#
# length=6169, comparison=19014642, less=0
#
# length=6168, comparison=19008475, less=0
#
# length=6167, comparison=19002309, less=0
#
# length=6166, comparison=18996144, less=0
#
# length=6165, comparison=18989980, less=0
#
# length=6164, comparison=18983817, less=0
#
# length=6163, comparison=18977655, less=0
#
# length=6162, comparison=18971494, less=0
#
# length=6161, comparison=18965334, less=0
#
# length=6160, comparison=18959175, less=0
#
# length=6159, comparison=18953017, less=0
#
# length=6158, comparison=18946860, less=0
#
# length=6157, comparison=18940704, less=0
#
# length=6156, comparison=18934549, less=0
#
# length=6155, comparison=18928395, less=0
#
# length=6154, comparison=18922242, less=0
#
# length=6153, comparison=18916090, less=0
#
# length=6152, comparison=18909939, less=0
#
# length=6151, comparison=18903789, less=0
#
# length=6150, comparison=18897640, less=0
#
# length=6149, comparison=18891492, less=0
#
# length=6148, comparison=18885345, less=0
#
# length=6147, comparison=18879199, less=0
#
# length=6146, comparison=18873054, less=0
#
# length=6145, comparison=18866910, less=0
#
# length=6144, comparison=18860767, less=0
#
# length=6143, comparison=18854625, less=0
#
# length=6142, comparison=18848484, less=0
#
# length=6141, comparison=18842344, less=0
#
# length=6140, comparison=18836205, less=0
#
# length=6139, comparison=18830067, less=0
#
# length=6138, comparison=18823930, less=0
#
# length=6137, comparison=18817794, less=0
#
# length=6136, comparison=18811659, less=0
#
# length=6135, comparison=18805525, less=0
#
# length=6134, comparison=18799392, less=0
#
# length=6133, comparison=18793260, less=0
#
# length=6132, comparison=18787129, less=0
#
# length=6131, comparison=18780999, less=0
#
# length=6130, comparison=18774870, less=0
#
# length=6129, comparison=18768742, less=0
#
# length=6128, comparison=18762615, less=0
#
# length=6127, comparison=18756489, less=0
#
# length=6126, comparison=18750364, less=0
#
# length=6125, comparison=18744240, less=0
#
# length=6124, comparison=18738117, less=0
#
# length=6123, comparison=18731995, less=0
#
# length=6122, comparison=18725874, less=0
#
# length=6121, comparison=18719754, less=0
#
# length=6120, comparison=18713635, less=0
#
# length=6119, comparison=18707517, less=0
#
# length=6118, comparison=18701400, less=0
#
# length=6117, comparison=18695284, less=0
#
# length=6116, comparison=18689169, less=0
#
# length=6115, comparison=18683055, less=0
#
# length=6114, comparison=18676942, less=0
#
# length=6113, comparison=18670830, less=0
#
# length=6112, comparison=18664719, less=0
#
# length=6111, comparison=18658609, less=0
#
# length=6110, comparison=18652500, less=0
#
# length=6109, comparison=18646392, less=0
#
# length=6108, comparison=18640285, less=0
#
# length=6107, comparison=18634179, less=0
#
# length=6106, comparison=18628074, less=0
#
# length=6105, comparison=18621970, less=0
#
# length=6104, comparison=18615867, less=0
#
# length=6103, comparison=18609765, less=0
#
# length=6102, comparison=18603664, less=0
#
# length=6101, comparison=18597564, less=0
#
# length=6100, comparison=18591465, less=0
#
# length=6099, comparison=18585367, less=0
#
# length=6098, comparison=18579270, less=0
#
# length=6097, comparison=18573174, less=0
#
# length=6096, comparison=18567079, less=0
#
# length=6095, comparison=18560985, less=0
#
# length=6094, comparison=18554892, less=0
#
# length=6093, comparison=18548800, less=0
#
# length=6092, comparison=18542709, less=0
#
# length=6091, comparison=18536619, less=0
#
# length=6090, comparison=18530530, less=0
#
# length=6089, comparison=18524442, less=0
#
# length=6088, comparison=18518355, less=0
#
# length=6087, comparison=18512269, less=0
#
# length=6086, comparison=18506184, less=0
#
# length=6085, comparison=18500100, less=0
#
# length=6084, comparison=18494017, less=0
#
# length=6083, comparison=18487935, less=0
#
# length=6082, comparison=18481854, less=0
#
# length=6081, comparison=18475774, less=0
#
# length=6080, comparison=18469695, less=0
#
# length=6079, comparison=18463617, less=0
#
# length=6078, comparison=18457540, less=0
#
# length=6077, comparison=18451464, less=0
#
# length=6076, comparison=18445389, less=0
#
# length=6075, comparison=18439315, less=0
#
# length=6074, comparison=18433242, less=0
#
# length=6073, comparison=18427170, less=0
#
# length=6072, comparison=18421099, less=0
#
# length=6071, comparison=18415029, less=0
#
# length=6070, comparison=18408960, less=0
#
# length=6069, comparison=18402892, less=0
#
# length=6068, comparison=18396825, less=0
#
# length=6067, comparison=18390759, less=0
#
# length=6066, comparison=18384694, less=0
#
# length=6065, comparison=18378630, less=0
#
# length=6064, comparison=18372567, less=0
#
# length=6063, comparison=18366505, less=0
#
# length=6062, comparison=18360444, less=0
#
# length=6061, comparison=18354384, less=0
#
# length=6060, comparison=18348325, less=0
#
# length=6059, comparison=18342267, less=0
#
# length=6058, comparison=18336210, less=0
#
# length=6057, comparison=18330154, less=0
#
# length=6056, comparison=18324099, less=0
#
# length=6055, comparison=18318045, less=0
#
# length=6054, comparison=18311992, less=0
#
# length=6053, comparison=18305940, less=0
#
# length=6052, comparison=18299889, less=0
#
# length=6051, comparison=18293839, less=0
#
# length=6050, comparison=18287790, less=0
#
# length=6049, comparison=18281742, less=0
#
# length=6048, comparison=18275695, less=0
#
# length=6047, comparison=18269649, less=0
#
# length=6046, comparison=18263604, less=0
#
# length=6045, comparison=18257560, less=0
#
# length=6044, comparison=18251517, less=0
#
# length=6043, comparison=18245475, less=0
#
# length=6042, comparison=18239434, less=0
#
# length=6041, comparison=18233394, less=0
#
# length=6040, comparison=18227355, less=0
#
# length=6039, comparison=18221317, less=0
#
# length=6038, comparison=18215280, less=0
#
# length=6037, comparison=18209244, less=0
#
# length=6036, comparison=18203209, less=0
#
# length=6035, comparison=18197175, less=0
#
# length=6034, comparison=18191142, less=0
#
# length=6033, comparison=18185110, less=0
#
# length=6032, comparison=18179079, less=0
#
# length=6031, comparison=18173049, less=0
#
# length=6030, comparison=18167020, less=0
#
# length=6029, comparison=18160992, less=0
#
# length=6028, comparison=18154965, less=0
#
# length=6027, comparison=18148939, less=0
#
# length=6026, comparison=18142914, less=0
#
# length=6025, comparison=18136890, less=0
#
# length=6024, comparison=18130867, less=0
#
# length=6023, comparison=18124845, less=0
#
# length=6022, comparison=18118824, less=0
#
# length=6021, comparison=18112804, less=0
#
# length=6020, comparison=18106785, less=0
#
# length=6019, comparison=18100767, less=0
#
# length=6018, comparison=18094750, less=0
#
# length=6017, comparison=18088734, less=0
#
# length=6016, comparison=18082719, less=0
#
# length=6015, comparison=18076705, less=0
#
# length=6014, comparison=18070692, less=0
#
# length=6013, comparison=18064680, less=0
#
# length=6012, comparison=18058669, less=0
#
# length=6011, comparison=18052659, less=0
#
# length=6010, comparison=18046650, less=0
#
# length=6009, comparison=18040642, less=0
#
# length=6008, comparison=18034635, less=0
#
# length=6007, comparison=18028629, less=0
#
# length=6006, comparison=18022624, less=0
#
# length=6005, comparison=18016620, less=0
#
# length=6004, comparison=18010617, less=0
#
# length=6003, comparison=18004615, less=0
#
# length=6002, comparison=17998614, less=0
#
# length=6001, comparison=17992614, less=0
#
# length=6000, comparison=17986615, less=0
#
# length=5999, comparison=17980617, less=0
#
# length=5998, comparison=17974620, less=0
#
# length=5997, comparison=17968624, less=0
#
# length=5996, comparison=17962629, less=0
#
# length=5995, comparison=17956635, less=0
#
# length=5994, comparison=17950642, less=0
#
# length=5993, comparison=17944650, less=0
#
# length=5992, comparison=17938659, less=0
#
# length=5991, comparison=17932669, less=0
#
# length=5990, comparison=17926680, less=0
#
# length=5989, comparison=17920692, less=0
#
# length=5988, comparison=17914705, less=0
#
# length=5987, comparison=17908719, less=0
#
# length=5986, comparison=17902734, less=0
#
# length=5985, comparison=17896750, less=0
#
# length=5984, comparison=17890767, less=0
#
# length=5983, comparison=17884785, less=0
#
# length=5982, comparison=17878804, less=0
#
# length=5981, comparison=17872824, less=0
#
# length=5980, comparison=17866845, less=0
#
# length=5979, comparison=17860867, less=0
#
# length=5978, comparison=17854890, less=0
#
# length=5977, comparison=17848914, less=0
#
# length=5976, comparison=17842939, less=0
#
# length=5975, comparison=17836965, less=0
#
# length=5974, comparison=17830992, less=0
#
# length=5973, comparison=17825020, less=0
#
# length=5972, comparison=17819049, less=0
#
# length=5971, comparison=17813079, less=0
#
# length=5970, comparison=17807110, less=0
#
# length=5969, comparison=17801142, less=0
#
# length=5968, comparison=17795175, less=0
#
# length=5967, comparison=17789209, less=0
#
# length=5966, comparison=17783244, less=0
#
# length=5965, comparison=17777280, less=0
#
# length=5964, comparison=17771317, less=0
#
# length=5963, comparison=17765355, less=0
#
# length=5962, comparison=17759394, less=0
#
# length=5961, comparison=17753434, less=0
#
# length=5960, comparison=17747475, less=0
#
# length=5959, comparison=17741517, less=0
#
# length=5958, comparison=17735560, less=0
#
# length=5957, comparison=17729604, less=0
#
# length=5956, comparison=17723649, less=0
#
# length=5955, comparison=17717695, less=0
#
# length=5954, comparison=17711742, less=0
#
# length=5953, comparison=17705790, less=0
#
# length=5952, comparison=17699839, less=0
#
# length=5951, comparison=17693889, less=0
#
# length=5950, comparison=17687940, less=0
#
# length=5949, comparison=17681992, less=0
#
# length=5948, comparison=17676045, less=0
#
# length=5947, comparison=17670099, less=0
#
# length=5946, comparison=17664154, less=0
#
# length=5945, comparison=17658210, less=0
#
# length=5944, comparison=17652267, less=0
#
# length=5943, comparison=17646325, less=0
#
# length=5942, comparison=17640384, less=0
#
# length=5941, comparison=17634444, less=0
#
# length=5940, comparison=17628505, less=0
#
# length=5939, comparison=17622567, less=0
#
# length=5938, comparison=17616630, less=0
#
# length=5937, comparison=17610694, less=0
#
# length=5936, comparison=17604759, less=0
#
# length=5935, comparison=17598825, less=0
#
# length=5934, comparison=17592892, less=0
#
# length=5933, comparison=17586960, less=0
#
# length=5932, comparison=17581029, less=0
#
# length=5931, comparison=17575099, less=0
#
# length=5930, comparison=17569170, less=0
#
# length=5929, comparison=17563242, less=0
#
# length=5928, comparison=17557315, less=0
#
# length=5927, comparison=17551389, less=0
#
# length=5926, comparison=17545464, less=0
#
# length=5925, comparison=17539540, less=0
#
# length=5924, comparison=17533617, less=0
#
# length=5923, comparison=17527695, less=0
#
# length=5922, comparison=17521774, less=0
#
# length=5921, comparison=17515854, less=0
#
# length=5920, comparison=17509935, less=0
#
# length=5919, comparison=17504017, less=0
#
# length=5918, comparison=17498100, less=0
#
# length=5917, comparison=17492184, less=0
#
# length=5916, comparison=17486269, less=0
#
# length=5915, comparison=17480355, less=0
#
# length=5914, comparison=17474442, less=0
#
# length=5913, comparison=17468530, less=0
#
# length=5912, comparison=17462619, less=0
#
# length=5911, comparison=17456709, less=0
#
# length=5910, comparison=17450800, less=0
#
# length=5909, comparison=17444892, less=0
#
# length=5908, comparison=17438985, less=0
#
# length=5907, comparison=17433079, less=0
#
# length=5906, comparison=17427174, less=0
#
# length=5905, comparison=17421270, less=0
#
# length=5904, comparison=17415367, less=0
#
# length=5903, comparison=17409465, less=0
#
# length=5902, comparison=17403564, less=0
#
# length=5901, comparison=17397664, less=0
#
# length=5900, comparison=17391765, less=0
#
# length=5899, comparison=17385867, less=0
#
# length=5898, comparison=17379970, less=0
#
# length=5897, comparison=17374074, less=0
#
# length=5896, comparison=17368179, less=0
#
# length=5895, comparison=17362285, less=0
#
# length=5894, comparison=17356392, less=0
#
# length=5893, comparison=17350500, less=0
#
# length=5892, comparison=17344609, less=0
#
# length=5891, comparison=17338719, less=0
#
# length=5890, comparison=17332830, less=0
#
# length=5889, comparison=17326942, less=0
#
# length=5888, comparison=17321055, less=0
#
# length=5887, comparison=17315169, less=0
#
# length=5886, comparison=17309284, less=0
#
# length=5885, comparison=17303400, less=0
#
# length=5884, comparison=17297517, less=0
#
# length=5883, comparison=17291635, less=0
#
# length=5882, comparison=17285754, less=0
#
# length=5881, comparison=17279874, less=0
#
# length=5880, comparison=17273995, less=0
#
# length=5879, comparison=17268117, less=0
#
# length=5878, comparison=17262240, less=0
#
# length=5877, comparison=17256364, less=0
#
# length=5876, comparison=17250489, less=0
#
# length=5875, comparison=17244615, less=0
#
# length=5874, comparison=17238742, less=0
#
# length=5873, comparison=17232870, less=0
#
# length=5872, comparison=17226999, less=0
#
# length=5871, comparison=17221129, less=0
#
# length=5870, comparison=17215260, less=0
#
# length=5869, comparison=17209392, less=0
#
# length=5868, comparison=17203525, less=0
#
# length=5867, comparison=17197659, less=0
#
# length=5866, comparison=17191794, less=0
#
# length=5865, comparison=17185930, less=0
#
# length=5864, comparison=17180067, less=0
#
# length=5863, comparison=17174205, less=0
#
# length=5862, comparison=17168344, less=0
#
# length=5861, comparison=17162484, less=0
#
# length=5860, comparison=17156625, less=0
#
# length=5859, comparison=17150767, less=0
#
# length=5858, comparison=17144910, less=0
#
# length=5857, comparison=17139054, less=0
#
# length=5856, comparison=17133199, less=0
#
# length=5855, comparison=17127345, less=0
#
# length=5854, comparison=17121492, less=0
#
# length=5853, comparison=17115640, less=0
#
# length=5852, comparison=17109789, less=0
#
# length=5851, comparison=17103939, less=0
#
# length=5850, comparison=17098090, less=0
#
# length=5849, comparison=17092242, less=0
#
# length=5848, comparison=17086395, less=0
#
# length=5847, comparison=17080549, less=0
#
# length=5846, comparison=17074704, less=0
#
# length=5845, comparison=17068860, less=0
#
# length=5844, comparison=17063017, less=0
#
# length=5843, comparison=17057175, less=0
#
# length=5842, comparison=17051334, less=0
#
# length=5841, comparison=17045494, less=0
#
# length=5840, comparison=17039655, less=0
#
# length=5839, comparison=17033817, less=0
#
# length=5838, comparison=17027980, less=0
#
# length=5837, comparison=17022144, less=0
#
# length=5836, comparison=17016309, less=0
#
# length=5835, comparison=17010475, less=0
#
# length=5834, comparison=17004642, less=0
#
# length=5833, comparison=16998810, less=0
#
# length=5832, comparison=16992979, less=0
#
# length=5831, comparison=16987149, less=0
#
# length=5830, comparison=16981320, less=0
#
# length=5829, comparison=16975492, less=0
#
# length=5828, comparison=16969665, less=0
#
# length=5827, comparison=16963839, less=0
#
# length=5826, comparison=16958014, less=0
#
# length=5825, comparison=16952190, less=0
#
# length=5824, comparison=16946367, less=0
#
# length=5823, comparison=16940545, less=0
#
# length=5822, comparison=16934724, less=0
#
# length=5821, comparison=16928904, less=0
#
# length=5820, comparison=16923085, less=0
#
# length=5819, comparison=16917267, less=0
#
# length=5818, comparison=16911450, less=0
#
# length=5817, comparison=16905634, less=0
#
# length=5816, comparison=16899819, less=0
#
# length=5815, comparison=16894005, less=0
#
# length=5814, comparison=16888192, less=0
#
# length=5813, comparison=16882380, less=0
#
# length=5812, comparison=16876569, less=0
#
# length=5811, comparison=16870759, less=0
#
# length=5810, comparison=16864950, less=0
#
# length=5809, comparison=16859142, less=0
#
# length=5808, comparison=16853335, less=0
#
# length=5807, comparison=16847529, less=0
#
# length=5806, comparison=16841724, less=0
#
# length=5805, comparison=16835920, less=0
#
# length=5804, comparison=16830117, less=0
#
# length=5803, comparison=16824315, less=0
#
# length=5802, comparison=16818514, less=0
#
# length=5801, comparison=16812714, less=0
#
# length=5800, comparison=16806915, less=0
#
# length=5799, comparison=16801117, less=0
#
# length=5798, comparison=16795320, less=0
#
# length=5797, comparison=16789524, less=0
#
# length=5796, comparison=16783729, less=0
#
# length=5795, comparison=16777935, less=0
#
# length=5794, comparison=16772142, less=0
#
# length=5793, comparison=16766350, less=0
#
# length=5792, comparison=16760559, less=0
#
# length=5791, comparison=16754769, less=0
#
# length=5790, comparison=16748980, less=0
#
# length=5789, comparison=16743192, less=0
#
# length=5788, comparison=16737405, less=0
#
# length=5787, comparison=16731619, less=0
#
# length=5786, comparison=16725834, less=0
#
# length=5785, comparison=16720050, less=0
#
# length=5784, comparison=16714267, less=0
#
# length=5783, comparison=16708485, less=0
#
# length=5782, comparison=16702704, less=0
#
# length=5781, comparison=16696924, less=0
#
# length=5780, comparison=16691145, less=0
#
# length=5779, comparison=16685367, less=0
#
# length=5778, comparison=16679590, less=0
#
# length=5777, comparison=16673814, less=0
#
# length=5776, comparison=16668039, less=0
#
# length=5775, comparison=16662265, less=0
#
# length=5774, comparison=16656492, less=0
#
# length=5773, comparison=16650720, less=0
#
# length=5772, comparison=16644949, less=0
#
# length=5771, comparison=16639179, less=0
#
# length=5770, comparison=16633410, less=0
#
# length=5769, comparison=16627642, less=0
#
# length=5768, comparison=16621875, less=0
#
# length=5767, comparison=16616109, less=0
#
# length=5766, comparison=16610344, less=0
#
# length=5765, comparison=16604580, less=0
#
# length=5764, comparison=16598817, less=0
#
# length=5763, comparison=16593055, less=0
#
# length=5762, comparison=16587294, less=0
#
# length=5761, comparison=16581534, less=0
#
# length=5760, comparison=16575775, less=0
#
# length=5759, comparison=16570017, less=0
#
# length=5758, comparison=16564260, less=0
#
# length=5757, comparison=16558504, less=0
#
# length=5756, comparison=16552749, less=0
#
# length=5755, comparison=16546995, less=0
#
# length=5754, comparison=16541242, less=0
#
# length=5753, comparison=16535490, less=0
#
# length=5752, comparison=16529739, less=0
#
# length=5751, comparison=16523989, less=0
#
# length=5750, comparison=16518240, less=0
#
# length=5749, comparison=16512492, less=0
#
# length=5748, comparison=16506745, less=0
#
# length=5747, comparison=16500999, less=0
#
# length=5746, comparison=16495254, less=0
#
# length=5745, comparison=16489510, less=0
#
# length=5744, comparison=16483767, less=0
#
# length=5743, comparison=16478025, less=0
#
# length=5742, comparison=16472284, less=0
#
# length=5741, comparison=16466544, less=0
#
# length=5740, comparison=16460805, less=0
#
# length=5739, comparison=16455067, less=0
#
# length=5738, comparison=16449330, less=0
#
# length=5737, comparison=16443594, less=0
#
# length=5736, comparison=16437859, less=0
#
# length=5735, comparison=16432125, less=0
#
# length=5734, comparison=16426392, less=0
#
# length=5733, comparison=16420660, less=0
#
# length=5732, comparison=16414929, less=0
#
# length=5731, comparison=16409199, less=0
#
# length=5730, comparison=16403470, less=0
#
# length=5729, comparison=16397742, less=0
#
# length=5728, comparison=16392015, less=0
#
# length=5727, comparison=16386289, less=0
#
# length=5726, comparison=16380564, less=0
#
# length=5725, comparison=16374840, less=0
#
# length=5724, comparison=16369117, less=0
#
# length=5723, comparison=16363395, less=0
#
# length=5722, comparison=16357674, less=0
#
# length=5721, comparison=16351954, less=0
#
# length=5720, comparison=16346235, less=0
#
# length=5719, comparison=16340517, less=0
#
# length=5718, comparison=16334800, less=0
#
# length=5717, comparison=16329084, less=0
#
# length=5716, comparison=16323369, less=0
#
# length=5715, comparison=16317655, less=0
#
# length=5714, comparison=16311942, less=0
#
# length=5713, comparison=16306230, less=0
#
# length=5712, comparison=16300519, less=0
#
# length=5711, comparison=16294809, less=0
#
# length=5710, comparison=16289100, less=0
#
# length=5709, comparison=16283392, less=0
#
# length=5708, comparison=16277685, less=0
#
# length=5707, comparison=16271979, less=0
#
# length=5706, comparison=16266274, less=0
#
# length=5705, comparison=16260570, less=0
#
# length=5704, comparison=16254867, less=0
#
# length=5703, comparison=16249165, less=0
#
# length=5702, comparison=16243464, less=0
#
# length=5701, comparison=16237764, less=0
#
# length=5700, comparison=16232065, less=0
#
# length=5699, comparison=16226367, less=0
#
# length=5698, comparison=16220670, less=0
#
# length=5697, comparison=16214974, less=0
#
# length=5696, comparison=16209279, less=0
#
# length=5695, comparison=16203585, less=0
#
# length=5694, comparison=16197892, less=0
#
# length=5693, comparison=16192200, less=0
#
# length=5692, comparison=16186509, less=0
#
# length=5691, comparison=16180819, less=0
#
# length=5690, comparison=16175130, less=0
#
# length=5689, comparison=16169442, less=0
#
# length=5688, comparison=16163755, less=0
#
# length=5687, comparison=16158069, less=0
#
# length=5686, comparison=16152384, less=0
#
# length=5685, comparison=16146700, less=0
#
# length=5684, comparison=16141017, less=0
#
# length=5683, comparison=16135335, less=0
#
# length=5682, comparison=16129654, less=0
#
# length=5681, comparison=16123974, less=0
#
# length=5680, comparison=16118295, less=0
#
# length=5679, comparison=16112617, less=0
#
# length=5678, comparison=16106940, less=0
#
# length=5677, comparison=16101264, less=0
#
# length=5676, comparison=16095589, less=0
#
# length=5675, comparison=16089915, less=0
#
# length=5674, comparison=16084242, less=0
#
# length=5673, comparison=16078570, less=0
#
# length=5672, comparison=16072899, less=0
#
# length=5671, comparison=16067229, less=0
#
# length=5670, comparison=16061560, less=0
#
# length=5669, comparison=16055892, less=0
#
# length=5668, comparison=16050225, less=0
#
# length=5667, comparison=16044559, less=0
#
# length=5666, comparison=16038894, less=0
#
# length=5665, comparison=16033230, less=0
#
# length=5664, comparison=16027567, less=0
#
# length=5663, comparison=16021905, less=0
#
# length=5662, comparison=16016244, less=0
#
# length=5661, comparison=16010584, less=0
#
# length=5660, comparison=16004925, less=0
#
# length=5659, comparison=15999267, less=0
#
# length=5658, comparison=15993610, less=0
#
# length=5657, comparison=15987954, less=0
#
# length=5656, comparison=15982299, less=0
#
# length=5655, comparison=15976645, less=0
#
# length=5654, comparison=15970992, less=0
#
# length=5653, comparison=15965340, less=0
#
# length=5652, comparison=15959689, less=0
#
# length=5651, comparison=15954039, less=0
#
# length=5650, comparison=15948390, less=0
#
# length=5649, comparison=15942742, less=0
#
# length=5648, comparison=15937095, less=0
#
# length=5647, comparison=15931449, less=0
#
# length=5646, comparison=15925804, less=0
#
# length=5645, comparison=15920160, less=0
#
# length=5644, comparison=15914517, less=0
#
# length=5643, comparison=15908875, less=0
#
# length=5642, comparison=15903234, less=0
#
# length=5641, comparison=15897594, less=0
#
# length=5640, comparison=15891955, less=0
#
# length=5639, comparison=15886317, less=0
#
# length=5638, comparison=15880680, less=0
#
# length=5637, comparison=15875044, less=0
#
# length=5636, comparison=15869409, less=0
#
# length=5635, comparison=15863775, less=0
#
# length=5634, comparison=15858142, less=0
#
# length=5633, comparison=15852510, less=0
#
# length=5632, comparison=15846879, less=0
#
# length=5631, comparison=15841249, less=0
#
# length=5630, comparison=15835620, less=0
#
# length=5629, comparison=15829992, less=0
#
# length=5628, comparison=15824365, less=0
#
# length=5627, comparison=15818739, less=0
#
# length=5626, comparison=15813114, less=0
#
# length=5625, comparison=15807490, less=0
#
# length=5624, comparison=15801867, less=0
#
# length=5623, comparison=15796245, less=0
#
# length=5622, comparison=15790624, less=0
#
# length=5621, comparison=15785004, less=0
#
# length=5620, comparison=15779385, less=0
#
# length=5619, comparison=15773767, less=0
#
# length=5618, comparison=15768150, less=0
#
# length=5617, comparison=15762534, less=0
#
# length=5616, comparison=15756919, less=0
#
# length=5615, comparison=15751305, less=0
#
# length=5614, comparison=15745692, less=0
#
# length=5613, comparison=15740080, less=0
#
# length=5612, comparison=15734469, less=0
#
# length=5611, comparison=15728859, less=0
#
# length=5610, comparison=15723250, less=0
#
# length=5609, comparison=15717642, less=0
#
# length=5608, comparison=15712035, less=0
#
# length=5607, comparison=15706429, less=0
#
# length=5606, comparison=15700824, less=0
#
# length=5605, comparison=15695220, less=0
#
# length=5604, comparison=15689617, less=0
#
# length=5603, comparison=15684015, less=0
#
# length=5602, comparison=15678414, less=0
#
# length=5601, comparison=15672814, less=0
#
# length=5600, comparison=15667215, less=0
#
# length=5599, comparison=15661617, less=0
#
# length=5598, comparison=15656020, less=0
#
# length=5597, comparison=15650424, less=0
#
# length=5596, comparison=15644829, less=0
#
# length=5595, comparison=15639235, less=0
#
# length=5594, comparison=15633642, less=0
#
# length=5593, comparison=15628050, less=0
#
# length=5592, comparison=15622459, less=0
#
# length=5591, comparison=15616869, less=0
#
# length=5590, comparison=15611280, less=0
#
# length=5589, comparison=15605692, less=0
#
# length=5588, comparison=15600105, less=0
#
# length=5587, comparison=15594519, less=0
#
# length=5586, comparison=15588934, less=0
#
# length=5585, comparison=15583350, less=0
#
# length=5584, comparison=15577767, less=0
#
# length=5583, comparison=15572185, less=0
#
# length=5582, comparison=15566604, less=0
#
# length=5581, comparison=15561024, less=0
#
# length=5580, comparison=15555445, less=0
#
# length=5579, comparison=15549867, less=0
#
# length=5578, comparison=15544290, less=0
#
# length=5577, comparison=15538714, less=0
#
# length=5576, comparison=15533139, less=0
#
# length=5575, comparison=15527565, less=0
#
# length=5574, comparison=15521992, less=0
#
# length=5573, comparison=15516420, less=0
#
# length=5572, comparison=15510849, less=0
#
# length=5571, comparison=15505279, less=0
#
# length=5570, comparison=15499710, less=0
#
# length=5569, comparison=15494142, less=0
#
# length=5568, comparison=15488575, less=0
#
# length=5567, comparison=15483009, less=0
#
# length=5566, comparison=15477444, less=0
#
# length=5565, comparison=15471880, less=0
#
# length=5564, comparison=15466317, less=0
#
# length=5563, comparison=15460755, less=0
#
# length=5562, comparison=15455194, less=0
#
# length=5561, comparison=15449634, less=0
#
# length=5560, comparison=15444075, less=0
#
# length=5559, comparison=15438517, less=0
#
# length=5558, comparison=15432960, less=0
#
# length=5557, comparison=15427404, less=0
#
# length=5556, comparison=15421849, less=0
#
# length=5555, comparison=15416295, less=0
#
# length=5554, comparison=15410742, less=0
#
# length=5553, comparison=15405190, less=0
#
# length=5552, comparison=15399639, less=0
#
# length=5551, comparison=15394089, less=0
#
# length=5550, comparison=15388540, less=0
#
# length=5549, comparison=15382992, less=0
#
# length=5548, comparison=15377445, less=0
#
# length=5547, comparison=15371899, less=0
#
# length=5546, comparison=15366354, less=0
#
# length=5545, comparison=15360810, less=0
#
# length=5544, comparison=15355267, less=0
#
# length=5543, comparison=15349725, less=0
#
# length=5542, comparison=15344184, less=0
#
# length=5541, comparison=15338644, less=0
#
# length=5540, comparison=15333105, less=0
#
# length=5539, comparison=15327567, less=0
#
# length=5538, comparison=15322030, less=0
#
# length=5537, comparison=15316494, less=0
#
# length=5536, comparison=15310959, less=0
#
# length=5535, comparison=15305425, less=0
#
# length=5534, comparison=15299892, less=0
#
# length=5533, comparison=15294360, less=0
#
# length=5532, comparison=15288829, less=0
#
# length=5531, comparison=15283299, less=0
#
# length=5530, comparison=15277770, less=0
#
# length=5529, comparison=15272242, less=0
#
# length=5528, comparison=15266715, less=0
#
# length=5527, comparison=15261189, less=0
#
# length=5526, comparison=15255664, less=0
#
# length=5525, comparison=15250140, less=0
#
# length=5524, comparison=15244617, less=0
#
# length=5523, comparison=15239095, less=0
#
# length=5522, comparison=15233574, less=0
#
# length=5521, comparison=15228054, less=0
#
# length=5520, comparison=15222535, less=0
#
# length=5519, comparison=15217017, less=0
#
# length=5518, comparison=15211500, less=0
#
# length=5517, comparison=15205984, less=0
#
# length=5516, comparison=15200469, less=0
#
# length=5515, comparison=15194955, less=0
#
# length=5514, comparison=15189442, less=0
#
# length=5513, comparison=15183930, less=0
#
# length=5512, comparison=15178419, less=0
#
# length=5511, comparison=15172909, less=0
#
# length=5510, comparison=15167400, less=0
#
# length=5509, comparison=15161892, less=0
#
# length=5508, comparison=15156385, less=0
#
# length=5507, comparison=15150879, less=0
#
# length=5506, comparison=15145374, less=0
#
# length=5505, comparison=15139870, less=0
#
# length=5504, comparison=15134367, less=0
#
# length=5503, comparison=15128865, less=0
#
# length=5502, comparison=15123364, less=0
#
# length=5501, comparison=15117864, less=0
#
# length=5500, comparison=15112365, less=0
#
# length=5499, comparison=15106867, less=0
#
# length=5498, comparison=15101370, less=0
#
# length=5497, comparison=15095874, less=0
#
# length=5496, comparison=15090379, less=0
#
# length=5495, comparison=15084885, less=0
#
# length=5494, comparison=15079392, less=0
#
# length=5493, comparison=15073900, less=0
#
# length=5492, comparison=15068409, less=0
#
# length=5491, comparison=15062919, less=0
#
# length=5490, comparison=15057430, less=0
#
# length=5489, comparison=15051942, less=0
#
# length=5488, comparison=15046455, less=0
#
# length=5487, comparison=15040969, less=0
#
# length=5486, comparison=15035484, less=0
#
# length=5485, comparison=15030000, less=0
#
# length=5484, comparison=15024517, less=0
#
# length=5483, comparison=15019035, less=0
#
# length=5482, comparison=15013554, less=0
#
# length=5481, comparison=15008074, less=0
#
# length=5480, comparison=15002595, less=0
#
# length=5479, comparison=14997117, less=0
#
# length=5478, comparison=14991640, less=0
#
# length=5477, comparison=14986164, less=0
#
# length=5476, comparison=14980689, less=0
#
# length=5475, comparison=14975215, less=0
#
# length=5474, comparison=14969742, less=0
#
# length=5473, comparison=14964270, less=0
#
# length=5472, comparison=14958799, less=0
#
# length=5471, comparison=14953329, less=0
#
# length=5470, comparison=14947860, less=0
#
# length=5469, comparison=14942392, less=0
#
# length=5468, comparison=14936925, less=0
#
# length=5467, comparison=14931459, less=0
#
# length=5466, comparison=14925994, less=0
#
# length=5465, comparison=14920530, less=0
#
# length=5464, comparison=14915067, less=0
#
# length=5463, comparison=14909605, less=0
#
# length=5462, comparison=14904144, less=0
#
# length=5461, comparison=14898684, less=0
#
# length=5460, comparison=14893225, less=0
#
# length=5459, comparison=14887767, less=0
#
# length=5458, comparison=14882310, less=0
#
# length=5457, comparison=14876854, less=0
#
# length=5456, comparison=14871399, less=0
#
# length=5455, comparison=14865945, less=0
#
# length=5454, comparison=14860492, less=0
#
# length=5453, comparison=14855040, less=0
#
# length=5452, comparison=14849589, less=0
#
# length=5451, comparison=14844139, less=0
#
# length=5450, comparison=14838690, less=0
#
# length=5449, comparison=14833242, less=0
#
# length=5448, comparison=14827795, less=0
#
# length=5447, comparison=14822349, less=0
#
# length=5446, comparison=14816904, less=0
#
# length=5445, comparison=14811460, less=0
#
# length=5444, comparison=14806017, less=0
#
# length=5443, comparison=14800575, less=0
#
# length=5442, comparison=14795134, less=0
#
# length=5441, comparison=14789694, less=0
#
# length=5440, comparison=14784255, less=0
#
# length=5439, comparison=14778817, less=0
#
# length=5438, comparison=14773380, less=0
#
# length=5437, comparison=14767944, less=0
#
# length=5436, comparison=14762509, less=0
#
# length=5435, comparison=14757075, less=0
#
# length=5434, comparison=14751642, less=0
#
# length=5433, comparison=14746210, less=0
#
# length=5432, comparison=14740779, less=0
#
# length=5431, comparison=14735349, less=0
#
# length=5430, comparison=14729920, less=0
#
# length=5429, comparison=14724492, less=0
#
# length=5428, comparison=14719065, less=0
#
# length=5427, comparison=14713639, less=0
#
# length=5426, comparison=14708214, less=0
#
# length=5425, comparison=14702790, less=0
#
# length=5424, comparison=14697367, less=0
#
# length=5423, comparison=14691945, less=0
#
# length=5422, comparison=14686524, less=0
#
# length=5421, comparison=14681104, less=0
#
# length=5420, comparison=14675685, less=0
#
# length=5419, comparison=14670267, less=0
#
# length=5418, comparison=14664850, less=0
#
# length=5417, comparison=14659434, less=0
#
# length=5416, comparison=14654019, less=0
#
# length=5415, comparison=14648605, less=0
#
# length=5414, comparison=14643192, less=0
#
# length=5413, comparison=14637780, less=0
#
# length=5412, comparison=14632369, less=0
#
# length=5411, comparison=14626959, less=0
#
# length=5410, comparison=14621550, less=0
#
# length=5409, comparison=14616142, less=0
#
# length=5408, comparison=14610735, less=0
#
# length=5407, comparison=14605329, less=0
#
# length=5406, comparison=14599924, less=0
#
# length=5405, comparison=14594520, less=0
#
# length=5404, comparison=14589117, less=0
#
# length=5403, comparison=14583715, less=0
#
# length=5402, comparison=14578314, less=0
#
# length=5401, comparison=14572914, less=0
#
# length=5400, comparison=14567515, less=0
#
# length=5399, comparison=14562117, less=0
#
# length=5398, comparison=14556720, less=0
#
# length=5397, comparison=14551324, less=0
#
# length=5396, comparison=14545929, less=0
#
# length=5395, comparison=14540535, less=0
#
# length=5394, comparison=14535142, less=0
#
# length=5393, comparison=14529750, less=0
#
# length=5392, comparison=14524359, less=0
#
# length=5391, comparison=14518969, less=0
#
# length=5390, comparison=14513580, less=0
#
# length=5389, comparison=14508192, less=0
#
# length=5388, comparison=14502805, less=0
#
# length=5387, comparison=14497419, less=0
#
# length=5386, comparison=14492034, less=0
#
# length=5385, comparison=14486650, less=0
#
# length=5384, comparison=14481267, less=0
#
# length=5383, comparison=14475885, less=0
#
# length=5382, comparison=14470504, less=0
#
# length=5381, comparison=14465124, less=0
#
# length=5380, comparison=14459745, less=0
#
# length=5379, comparison=14454367, less=0
#
# length=5378, comparison=14448990, less=0
#
# length=5377, comparison=14443614, less=0
#
# length=5376, comparison=14438239, less=0
#
# length=5375, comparison=14432865, less=0
#
# length=5374, comparison=14427492, less=0
#
# length=5373, comparison=14422120, less=0
#
# length=5372, comparison=14416749, less=0
#
# length=5371, comparison=14411379, less=0
#
# length=5370, comparison=14406010, less=0
#
# length=5369, comparison=14400642, less=0
#
# length=5368, comparison=14395275, less=0
#
# length=5367, comparison=14389909, less=0
#
# length=5366, comparison=14384544, less=0
#
# length=5365, comparison=14379180, less=0
#
# length=5364, comparison=14373817, less=0
#
# length=5363, comparison=14368455, less=0
#
# length=5362, comparison=14363094, less=0
#
# length=5361, comparison=14357734, less=0
#
# length=5360, comparison=14352375, less=0
#
# length=5359, comparison=14347017, less=0
#
# length=5358, comparison=14341660, less=0
#
# length=5357, comparison=14336304, less=0
#
# length=5356, comparison=14330949, less=0
#
# length=5355, comparison=14325595, less=0
#
# length=5354, comparison=14320242, less=0
#
# length=5353, comparison=14314890, less=0
#
# length=5352, comparison=14309539, less=0
#
# length=5351, comparison=14304189, less=0
#
# length=5350, comparison=14298840, less=0
#
# length=5349, comparison=14293492, less=0
#
# length=5348, comparison=14288145, less=0
#
# length=5347, comparison=14282799, less=0
#
# length=5346, comparison=14277454, less=0
#
# length=5345, comparison=14272110, less=0
#
# length=5344, comparison=14266767, less=0
#
# length=5343, comparison=14261425, less=0
#
# length=5342, comparison=14256084, less=0
#
# length=5341, comparison=14250744, less=0
#
# length=5340, comparison=14245405, less=0
#
# length=5339, comparison=14240067, less=0
#
# length=5338, comparison=14234730, less=0
#
# length=5337, comparison=14229394, less=0
#
# length=5336, comparison=14224059, less=0
#
# length=5335, comparison=14218725, less=0
#
# length=5334, comparison=14213392, less=0
#
# length=5333, comparison=14208060, less=0
#
# length=5332, comparison=14202729, less=0
#
# length=5331, comparison=14197399, less=0
#
# length=5330, comparison=14192070, less=0
#
# length=5329, comparison=14186742, less=0
#
# length=5328, comparison=14181415, less=0
#
# length=5327, comparison=14176089, less=0
#
# length=5326, comparison=14170764, less=0
#
# length=5325, comparison=14165440, less=0
#
# length=5324, comparison=14160117, less=0
#
# length=5323, comparison=14154795, less=0
#
# length=5322, comparison=14149474, less=0
#
# length=5321, comparison=14144154, less=0
#
# length=5320, comparison=14138835, less=0
#
# length=5319, comparison=14133517, less=0
#
# length=5318, comparison=14128200, less=0
#
# length=5317, comparison=14122884, less=0
#
# length=5316, comparison=14117569, less=0
#
# length=5315, comparison=14112255, less=0
#
# length=5314, comparison=14106942, less=0
#
# length=5313, comparison=14101630, less=0
#
# length=5312, comparison=14096319, less=0
#
# length=5311, comparison=14091009, less=0
#
# length=5310, comparison=14085700, less=0
#
# length=5309, comparison=14080392, less=0
#
# length=5308, comparison=14075085, less=0
#
# length=5307, comparison=14069779, less=0
#
# length=5306, comparison=14064474, less=0
#
# length=5305, comparison=14059170, less=0
#
# length=5304, comparison=14053867, less=0
#
# length=5303, comparison=14048565, less=0
#
# length=5302, comparison=14043264, less=0
#
# length=5301, comparison=14037964, less=0
#
# length=5300, comparison=14032665, less=0
#
# length=5299, comparison=14027367, less=0
#
# length=5298, comparison=14022070, less=0
#
# length=5297, comparison=14016774, less=0
#
# length=5296, comparison=14011479, less=0
#
# length=5295, comparison=14006185, less=0
#
# length=5294, comparison=14000892, less=0
#
# length=5293, comparison=13995600, less=0
#
# length=5292, comparison=13990309, less=0
#
# length=5291, comparison=13985019, less=0
#
# length=5290, comparison=13979730, less=0
#
# length=5289, comparison=13974442, less=0
#
# length=5288, comparison=13969155, less=0
#
# length=5287, comparison=13963869, less=0
#
# length=5286, comparison=13958584, less=0
#
# length=5285, comparison=13953300, less=0
#
# length=5284, comparison=13948017, less=0
#
# length=5283, comparison=13942735, less=0
#
# length=5282, comparison=13937454, less=0
#
# length=5281, comparison=13932174, less=0
#
# length=5280, comparison=13926895, less=0
#
# length=5279, comparison=13921617, less=0
#
# length=5278, comparison=13916340, less=0
#
# length=5277, comparison=13911064, less=0
#
# length=5276, comparison=13905789, less=0
#
# length=5275, comparison=13900515, less=0
#
# length=5274, comparison=13895242, less=0
#
# length=5273, comparison=13889970, less=0
#
# length=5272, comparison=13884699, less=0
#
# length=5271, comparison=13879429, less=0
#
# length=5270, comparison=13874160, less=0
#
# length=5269, comparison=13868892, less=0
#
# length=5268, comparison=13863625, less=0
#
# length=5267, comparison=13858359, less=0
#
# length=5266, comparison=13853094, less=0
#
# length=5265, comparison=13847830, less=0
#
# length=5264, comparison=13842567, less=0
#
# length=5263, comparison=13837305, less=0
#
# length=5262, comparison=13832044, less=0
#
# length=5261, comparison=13826784, less=0
#
# length=5260, comparison=13821525, less=0
#
# length=5259, comparison=13816267, less=0
#
# length=5258, comparison=13811010, less=0
#
# length=5257, comparison=13805754, less=0
#
# length=5256, comparison=13800499, less=0
#
# length=5255, comparison=13795245, less=0
#
# length=5254, comparison=13789992, less=0
#
# length=5253, comparison=13784740, less=0
#
# length=5252, comparison=13779489, less=0
#
# length=5251, comparison=13774239, less=0
#
# length=5250, comparison=13768990, less=0
#
# length=5249, comparison=13763742, less=0
#
# length=5248, comparison=13758495, less=0
#
# length=5247, comparison=13753249, less=0
#
# length=5246, comparison=13748004, less=0
#
# length=5245, comparison=13742760, less=0
#
# length=5244, comparison=13737517, less=0
#
# length=5243, comparison=13732275, less=0
#
# length=5242, comparison=13727034, less=0
#
# length=5241, comparison=13721794, less=0
#
# length=5240, comparison=13716555, less=0
#
# length=5239, comparison=13711317, less=0
#
# length=5238, comparison=13706080, less=0
#
# length=5237, comparison=13700844, less=0
#
# length=5236, comparison=13695609, less=0
#
# length=5235, comparison=13690375, less=0
#
# length=5234, comparison=13685142, less=0
#
# length=5233, comparison=13679910, less=0
#
# length=5232, comparison=13674679, less=0
#
# length=5231, comparison=13669449, less=0
#
# length=5230, comparison=13664220, less=0
#
# length=5229, comparison=13658992, less=0
#
# length=5228, comparison=13653765, less=0
#
# length=5227, comparison=13648539, less=0
#
# length=5226, comparison=13643314, less=0
#
# length=5225, comparison=13638090, less=0
#
# length=5224, comparison=13632867, less=0
#
# length=5223, comparison=13627645, less=0
#
# length=5222, comparison=13622424, less=0
#
# length=5221, comparison=13617204, less=0
#
# length=5220, comparison=13611985, less=0
#
# length=5219, comparison=13606767, less=0
#
# length=5218, comparison=13601550, less=0
#
# length=5217, comparison=13596334, less=0
#
# length=5216, comparison=13591119, less=0
#
# length=5215, comparison=13585905, less=0
#
# length=5214, comparison=13580692, less=0
#
# length=5213, comparison=13575480, less=0
#
# length=5212, comparison=13570269, less=0
#
# length=5211, comparison=13565059, less=0
#
# length=5210, comparison=13559850, less=0
#
# ...
#
# length=515, comparison=127455, less=0
#
# length=514, comparison=126942, less=0
#
# length=513, comparison=126430, less=0
#
# length=512, comparison=125919, less=0
#
# length=511, comparison=125409, less=0
#
# length=510, comparison=124900, less=0
#
# length=509, comparison=124392, less=0
#
# length=508, comparison=123885, less=0
#
# length=507, comparison=123379, less=0
#
# length=506, comparison=122874, less=0
#
# length=505, comparison=122370, less=0
#
# length=504, comparison=121867, less=0
#
# length=503, comparison=121365, less=0
#
# length=502, comparison=120864, less=0
#
# length=501, comparison=120364, less=0
#
# length=500, comparison=119865, less=0
#
# length=499, comparison=119367, less=0
#
# length=498, comparison=118870, less=0
#
# length=497, comparison=118374, less=0
#
# length=496, comparison=117879, less=0
#
# length=495, comparison=117385, less=0
#
# length=494, comparison=116892, less=0
#
# length=493, comparison=116400, less=0
#
# length=492, comparison=115909, less=0
#
# length=491, comparison=115419, less=0
#
# length=490, comparison=114930, less=0
#
# length=489, comparison=114442, less=0
#
# length=488, comparison=113955, less=0
#
# length=487, comparison=113469, less=0
#
# length=486, comparison=112984, less=0
#
# length=485, comparison=112500, less=0
#
# length=484, comparison=112017, less=0
#
# length=483, comparison=111535, less=0
#
# length=482, comparison=111054, less=0
#
# length=481, comparison=110574, less=0
#
# length=480, comparison=110095, less=0
#
# length=479, comparison=109617, less=0
#
# length=478, comparison=109140, less=0
#
# length=477, comparison=108664, less=0
#
# length=476, comparison=108189, less=0
#
# length=475, comparison=107715, less=0
#
# length=474, comparison=107242, less=0
#
# length=473, comparison=106770, less=0
#
# length=472, comparison=106299, less=0
#
# length=471, comparison=105829, less=0
#
# length=470, comparison=105360, less=0
#
# length=469, comparison=104892, less=0
#
# length=468, comparison=104425, less=0
#
# length=467, comparison=103959, less=0
#
# length=466, comparison=103494, less=0
#
# length=465, comparison=103030, less=0
#
# length=464, comparison=102567, less=0
#
# length=463, comparison=102105, less=0
#
# length=462, comparison=101644, less=0
#
# length=461, comparison=101184, less=0
#
# length=460, comparison=100725, less=0
#
# length=459, comparison=100267, less=0
#
# length=458, comparison=99810, less=0
#
# length=457, comparison=99354, less=0
#
# length=456, comparison=98899, less=0
#
# length=455, comparison=98445, less=0
#
# length=454, comparison=97992, less=0
#
# length=453, comparison=97540, less=0
#
# length=452, comparison=97089, less=0
#
# length=451, comparison=96639, less=0
#
# length=450, comparison=96190, less=0
#
# length=449, comparison=95742, less=0
#
# length=448, comparison=95295, less=0
#
# length=447, comparison=94849, less=0
#
# length=446, comparison=94404, less=0
#
# length=445, comparison=93960, less=0
#
# length=444, comparison=93517, less=0
#
# length=443, comparison=93075, less=0
#
# length=442, comparison=92634, less=0
#
# length=441, comparison=92194, less=0
#
# length=440, comparison=91755, less=0
#
# length=439, comparison=91317, less=0
#
# length=438, comparison=90880, less=0
#
# length=437, comparison=90444, less=0
#
# length=436, comparison=90009, less=0
#
# length=435, comparison=89575, less=0
#
# length=434, comparison=89142, less=0
#
# length=433, comparison=88710, less=0
#
# length=432, comparison=88279, less=0
#
# length=431, comparison=87849, less=0
#
# length=430, comparison=87420, less=0
#
# length=429, comparison=86992, less=0
#
# length=428, comparison=86565, less=0
#
# length=427, comparison=86139, less=0
#
# length=426, comparison=85714, less=0
#
# length=425, comparison=85290, less=0
#
# length=424, comparison=84867, less=0
#
# length=423, comparison=84445, less=0
#
# length=422, comparison=84024, less=0
#
# length=421, comparison=83604, less=0
#
# length=420, comparison=83185, less=0
#
# length=419, comparison=82767, less=0
#
# length=418, comparison=82350, less=0
#
# length=417, comparison=81934, less=0
#
# length=416, comparison=81519, less=0
#
# length=415, comparison=81105, less=0
#
# length=414, comparison=80692, less=0
#
# length=413, comparison=80280, less=0
#
# length=412, comparison=79869, less=0
#
# length=411, comparison=79459, less=0
#
# length=410, comparison=79050, less=0
#
# length=409, comparison=78642, less=0
#
# length=408, comparison=78235, less=0
#
# length=407, comparison=77829, less=0
#
# length=406, comparison=77424, less=0
#
# length=405, comparison=77020, less=0
#
# length=404, comparison=76617, less=0
#
# length=403, comparison=76215, less=0
#
# length=402, comparison=75814, less=0
#
# length=401, comparison=75414, less=0
#
# length=400, comparison=75015, less=0
#
# length=399, comparison=74617, less=0
#
# length=398, comparison=74220, less=0
#
# length=397, comparison=73824, less=0
#
# length=396, comparison=73429, less=0
#
# length=395, comparison=73035, less=0
#
# length=394, comparison=72642, less=0
#
# length=393, comparison=72250, less=0
#
# length=392, comparison=71859, less=0
#
# length=391, comparison=71469, less=0
#
# length=390, comparison=71080, less=0
#
# length=389, comparison=70692, less=0
#
# length=388, comparison=70305, less=0
#
# length=387, comparison=69919, less=0
#
# length=386, comparison=69534, less=0
#
# length=385, comparison=69150, less=0
#
# length=384, comparison=68767, less=0
#
# length=383, comparison=68385, less=0
#
# length=382, comparison=68004, less=0
#
# length=381, comparison=67624, less=0
#
# length=380, comparison=67245, less=0
#
# length=379, comparison=66867, less=0
#
# length=378, comparison=66490, less=0
#
# length=377, comparison=66114, less=0
#
# length=376, comparison=65739, less=0
#
# length=375, comparison=65365, less=0
#
# length=374, comparison=64992, less=0
#
# length=373, comparison=64620, less=0
#
# length=372, comparison=64249, less=0
#
# length=371, comparison=63879, less=0
#
# length=370, comparison=63510, less=0
#
# length=369, comparison=63142, less=0
#
# length=368, comparison=62775, less=0
#
# length=367, comparison=62409, less=0
#
# length=366, comparison=62044, less=0
#
# length=365, comparison=61680, less=0
#
# length=364, comparison=61317, less=0
#
# length=363, comparison=60955, less=0
#
# length=362, comparison=60594, less=0
#
# length=361, comparison=60234, less=0
#
# length=360, comparison=59875, less=0
#
# length=359, comparison=59517, less=0
#
# length=358, comparison=59160, less=0
#
# length=357, comparison=58804, less=0
#
# length=356, comparison=58449, less=0
#
# length=355, comparison=58095, less=0
#
# length=354, comparison=57742, less=0
#
# length=353, comparison=57390, less=0
#
# length=352, comparison=57039, less=0
#
# length=351, comparison=56689, less=0
#
# length=350, comparison=56340, less=0
#
# length=349, comparison=55992, less=0
#
# length=348, comparison=55645, less=0
#
# length=347, comparison=55299, less=0
#
# length=346, comparison=54954, less=0
#
# length=345, comparison=54610, less=0
#
# length=344, comparison=54267, less=0
#
# length=343, comparison=53925, less=0
#
# length=342, comparison=53584, less=0
#
# length=341, comparison=53244, less=0
#
# length=340, comparison=52905, less=0
#
# length=339, comparison=52567, less=0
#
# length=338, comparison=52230, less=0
#
# length=337, comparison=51894, less=0
#
# length=336, comparison=51559, less=0
#
# length=335, comparison=51225, less=0
#
# length=334, comparison=50892, less=0
#
# length=333, comparison=50560, less=0
#
# length=332, comparison=50229, less=0
#
# length=331, comparison=49899, less=0
#
# length=330, comparison=49570, less=0
#
# length=329, comparison=49242, less=0
#
# length=328, comparison=48915, less=0
#
# length=327, comparison=48589, less=0
#
# length=326, comparison=48264, less=0
#
# length=325, comparison=47940, less=0
#
# length=324, comparison=47617, less=0
#
# length=323, comparison=47295, less=0
#
# length=322, comparison=46974, less=0
#
# length=321, comparison=46654, less=0
#
# length=320, comparison=46335, less=0
#
# length=319, comparison=46017, less=0
#
# length=318, comparison=45700, less=0
#
# length=317, comparison=45384, less=0
#
# length=316, comparison=45069, less=0
#
# length=315, comparison=44755, less=0
#
# length=314, comparison=44442, less=0
#
# length=313, comparison=44130, less=0
#
# length=312, comparison=43819, less=0
#
# length=311, comparison=43509, less=0
#
# length=310, comparison=43200, less=0
#
# length=309, comparison=42892, less=0
#
# length=308, comparison=42585, less=0
#
# length=307, comparison=42279, less=0
#
# length=306, comparison=41974, less=0
#
# length=305, comparison=41670, less=0
#
# length=304, comparison=41367, less=0
#
# length=303, comparison=41065, less=0
#
# length=302, comparison=40764, less=0
#
# length=301, comparison=40464, less=0
#
# length=300, comparison=40165, less=0
#
# length=299, comparison=39867, less=0
#
# length=298, comparison=39570, less=0
#
# length=297, comparison=39274, less=0
#
# length=296, comparison=38979, less=0
#
# length=295, comparison=38685, less=0
#
# length=294, comparison=38392, less=0
#
# length=293, comparison=38100, less=0
#
# length=292, comparison=37809, less=0
#
# length=291, comparison=37519, less=0
#
# length=290, comparison=37230, less=0
#
# length=289, comparison=36942, less=0
#
# length=288, comparison=36655, less=0
#
# length=287, comparison=36369, less=0
#
# length=286, comparison=36084, less=0
#
# length=285, comparison=35800, less=0
#
# length=284, comparison=35517, less=0
#
# length=283, comparison=35235, less=0
#
# length=282, comparison=34954, less=0
#
# length=281, comparison=34674, less=0
#
# length=280, comparison=34395, less=0
#
# length=279, comparison=34117, less=0
#
# length=278, comparison=33840, less=0
#
# length=277, comparison=33564, less=0
#
# length=276, comparison=33289, less=0
#
# length=275, comparison=33015, less=0
#
# length=274, comparison=32742, less=0
#
# length=273, comparison=32470, less=0
#
# length=272, comparison=32199, less=0
#
# length=271, comparison=31929, less=0
#
# length=270, comparison=31660, less=0
#
# length=269, comparison=31392, less=0
#
# length=268, comparison=31125, less=0
#
# length=267, comparison=30859, less=0
#
# length=266, comparison=30594, less=0
#
# length=265, comparison=30330, less=0
#
# length=264, comparison=30067, less=0
#
# length=263, comparison=29805, less=0
#
# length=262, comparison=29544, less=0
#
# length=261, comparison=29284, less=0
#
# length=260, comparison=29025, less=0
#
# length=259, comparison=28767, less=0
#
# length=258, comparison=28510, less=0
#
# length=257, comparison=28254, less=0
#
# length=256, comparison=27999, less=0
#
# length=255, comparison=27745, less=0
#
# length=254, comparison=27492, less=0
#
# length=253, comparison=27240, less=0
#
# length=252, comparison=26989, less=0
#
# length=251, comparison=26739, less=0
#
# length=250, comparison=26490, less=0
#
# length=249, comparison=26242, less=0
#
# length=248, comparison=25995, less=0
#
# length=247, comparison=25749, less=0
#
# length=246, comparison=25504, less=0
#
# length=245, comparison=25260, less=0
#
# length=244, comparison=25017, less=0
#
# length=243, comparison=24775, less=0
#
# length=242, comparison=24534, less=0
#
# length=241, comparison=24294, less=0
#
# length=240, comparison=24055, less=0
#
# length=239, comparison=23817, less=0
#
# length=238, comparison=23580, less=0
#
# length=237, comparison=23344, less=0
#
# length=236, comparison=23109, less=0
#
# length=235, comparison=22875, less=0
#
# length=234, comparison=22642, less=0
#
# length=233, comparison=22410, less=0
#
# length=232, comparison=22179, less=0
#
# length=231, comparison=21949, less=0
#
# length=230, comparison=21720, less=0
#
# length=229, comparison=21492, less=0
#
# length=228, comparison=21265, less=0
#
# length=227, comparison=21039, less=0
#
# length=226, comparison=20814, less=0
#
# length=225, comparison=20590, less=0
#
# length=224, comparison=20367, less=0
#
# length=223, comparison=20145, less=0
#
# length=222, comparison=19924, less=0
#
# length=221, comparison=19704, less=0
#
# length=220, comparison=19485, less=0
#
# length=219, comparison=19267, less=0
#
# length=218, comparison=19050, less=0
#
# length=217, comparison=18834, less=0
#
# length=216, comparison=18619, less=0
#
# length=215, comparison=18405, less=0
#
# length=214, comparison=18192, less=0
#
# length=213, comparison=17980, less=0
#
# length=212, comparison=17769, less=0
#
# length=211, comparison=17559, less=0
#
# length=210, comparison=17350, less=0
#
# length=209, comparison=17142, less=0
#
# length=208, comparison=16935, less=0
#
# length=207, comparison=16729, less=0
#
# length=206, comparison=16524, less=0
#
# length=205, comparison=16320, less=0
#
# length=204, comparison=16117, less=0
#
# length=203, comparison=15915, less=0
#
# length=202, comparison=15714, less=0
#
# length=201, comparison=15514, less=0
#
# length=200, comparison=15315, less=0
#
# length=199, comparison=15117, less=0
#
# length=198, comparison=14920, less=0
#
# length=197, comparison=14724, less=0
#
# length=196, comparison=14529, less=0
#
# length=195, comparison=14335, less=0
#
# length=194, comparison=14142, less=0
#
# length=193, comparison=13950, less=0
#
# length=192, comparison=13759, less=0
#
# length=191, comparison=13569, less=0
#
# length=190, comparison=13380, less=0
#
# length=189, comparison=13192, less=0
#
# length=188, comparison=13005, less=0
#
# length=187, comparison=12819, less=0
#
# length=186, comparison=12634, less=0
#
# length=185, comparison=12450, less=0
#
# length=184, comparison=12267, less=0
#
# length=183, comparison=12085, less=0
#
# length=182, comparison=11904, less=0
#
# length=181, comparison=11724, less=0
#
# length=180, comparison=11545, less=0
#
# length=179, comparison=11367, less=0
#
# length=178, comparison=11190, less=0
#
# length=177, comparison=11014, less=0
#
# length=176, comparison=10839, less=0
#
# length=175, comparison=10665, less=0
#
# length=174, comparison=10492, less=0
#
# length=173, comparison=10320, less=0
#
# length=172, comparison=10149, less=0
#
# length=171, comparison=9979, less=0
#
# length=170, comparison=9810, less=0
#
# length=169, comparison=9642, less=0
#
# length=168, comparison=9475, less=0
#
# length=167, comparison=9309, less=0
#
# length=166, comparison=9144, less=0
#
# length=165, comparison=8980, less=0
#
# length=164, comparison=8817, less=0
#
# length=163, comparison=8655, less=0
#
# length=162, comparison=8494, less=0
#
# length=161, comparison=8334, less=0
#
# length=160, comparison=8175, less=0
#
# length=159, comparison=8017, less=0
#
# length=158, comparison=7860, less=0
#
# length=157, comparison=7704, less=0
#
# length=156, comparison=7549, less=0
#
# length=155, comparison=7395, less=0
#
# length=154, comparison=7242, less=0
#
# length=153, comparison=7090, less=0
#
# length=152, comparison=6939, less=0
#
# length=151, comparison=6789, less=0
#
# length=150, comparison=6640, less=0
#
# length=149, comparison=6492, less=0
#
# length=148, comparison=6345, less=0
#
# length=147, comparison=6199, less=0
#
# length=146, comparison=6054, less=0
#
# length=145, comparison=5910, less=0
#
# length=144, comparison=5767, less=0
#
# length=143, comparison=5625, less=0
#
# length=142, comparison=5484, less=0
#
# length=141, comparison=5344, less=0
#
# length=140, comparison=5205, less=0
#
# length=139, comparison=5067, less=0
#
# length=138, comparison=4930, less=0
#
# length=137, comparison=4794, less=0
#
# length=136, comparison=4659, less=0
#
# length=135, comparison=4525, less=0
#
# length=134, comparison=4392, less=0
#
# length=133, comparison=4260, less=0
#
# length=132, comparison=4129, less=0
#
# length=131, comparison=3999, less=0
#
# length=130, comparison=3870, less=0
#
# length=129, comparison=3742, less=0
#
# length=128, comparison=3615, less=0
#
# length=127, comparison=3489, less=0
#
# length=126, comparison=3364, less=0
#
# length=125, comparison=3240, less=0
#
# length=124, comparison=3117, less=0
#
# length=123, comparison=2995, less=0
#
# length=122, comparison=2874, less=0
#
# length=121, comparison=2754, less=0
#
# length=120, comparison=2635, less=0
#
# length=119, comparison=2517, less=0
#
# length=118, comparison=2400, less=0
#
# length=117, comparison=2284, less=0
#
# length=116, comparison=2169, less=0
#
# length=115, comparison=2055, less=0
#
# length=114, comparison=1942, less=0
#
# length=113, comparison=1830, less=0
#
# length=112, comparison=1719, less=0
#
# length=111, comparison=1609, less=0
#
# length=110, comparison=1500, less=0
#
# length=109, comparison=1392, less=0
#
# length=108, comparison=1285, less=0
#
# length=107, comparison=1179, less=0
#
# length=106, comparison=1074, less=0
#
# length=105, comparison=970, less=0
#
# length=104, comparison=867, less=0
#
# length=103, comparison=765, less=0
#
# length=102, comparison=664, less=0
#
# length=101, comparison=564, less=0
#
# length=100, comparison=465, less=2
#
# length=97, comparison=368, less=31
#
# length=31, comparison=68, less=15
#
# length=15, comparison=20, less=7
#
# length=7, comparison=4, less=3
#
# length=3, comparison=0, less=1
# done
# 0.672
# True

# %%
df = pd.read_csv('data/input03.txt', sep='\s+')
num_queries = df.columns[0]
df = df.reset_index().rename(columns={'index': 'length', num_queries: 'comparisons'})
queries = df.values
type(queries[0][0])
# Out:
# numpy.int64

# %%
smallest = get_smallest(queries[:, 0].max())
# print(smallest)
time0 = time()
for length, comparisons in queries:
    print(isinstance(length, np.int64), isinstance(comparisons, int))
    arr = find_arr(length, comparisons)
    _, c = lena_sort(arr)
    print(f'{comparisons}, {c}')
# Out:
# True False
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-9ecd84d51847> in <module>
#       4 for length, comparisons in queries:
#       5     print(isinstance(length, np.int64), isinstance(comparisons, int))
# ----> 6     arr = find_arr(length, comparisons)
#       7     _, c = lena_sort(arr)
#       8     print(f'{comparisons}, {c}')
#
# <ipython-input-34-4c6406206cc0> in find_arr(length, comparisons)
#      88
#      89     # print(f'pivot = {pivot}, less = {less}, more = {more}, comparisons_more = {comparisons_more}')
# ---> 90     return [pivot] + list(range(1, pivot)) + rec(more, comparisons_more, pivot + 1)
#      91
#      92
#
# <ipython-input-34-4c6406206cc0> in rec(length, comparisons, first)
#      66         comparisons_less = upper
#      67         A = rec(less, comparisons_less, first)
# ---> 68         B = get_min_arr(more, pivot + 1)
#      69     else: # upper == max_less
#      70         comparisons_less = upper
#
# <ipython-input-34-4c6406206cc0> in get_min_arr(length, start)
#      17                 new_memo.append(m)
#      18             else:
# ---> 19                 s, l = m
#      20                 middle = s + (l - 1) // 2
#      21                 new_memo.append(middle)
#
# TypeError: cannot unpack non-iterable numpy.int64 object

# %%
! cat data/input11.txt
# Out:
# 8
# 100000 675013257
# 100000 475595761
# 100000 0
# 100000 323932335
# 100000 1468946
# 100000 1000000000
# 100000 468586326
# 100000 986975
